# %%
import pandas as pd
import numpy as np
import rpy2.robjects as robjects
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri

pandas2ri.activate()

from PyCRO_SL import *
from PyCRO_SL.CRO_SL import CRO_SL
from PyCRO_SL.AbsObjetiveFunc import AbsObjetiveFunc
from PyCRO_SL.SubstrateInt import SubstrateInt
from PyCRO_SL.SubstrateReal import SubstrateReal
import random

# %%
class HydroProblemSemidist(AbsObjetiveFunc):
    def __init__(self, rscript_name='exec_problem_semidist.R', metric="MSE", model_used=0, basin_code=-1, prev_q=0):         
        # Defining the R script and loading the instance in Python
        r = robjects.r
        r['source'](rscript_name)

        inf_lim = np.array([1e-4,10,0,1e-4,1e-4,2,-6])
        sup_lim = np.array([1,2000,1,100,1,11,1])
        self.size = 7

        self.metric = metric
        self.model_used = model_used
        self.basin_code = basin_code
        self.prev_q = prev_q

        opt = "min"
        if metric in ["KGE", "NSE"]:
            opt = "max"

        # Loading the function we have defined in R.
        self.exec_function_r = robjects.globalenv['eval_basin_param']
        super().__init__(self.size, opt, sup_lim, inf_lim)

    def objetive(self, solution):
        metrics = self.exec_function_r(self.model_used, solution, self.basin_code, self.prev_q)
        if self.metric == "MSE":
            return float(metrics[0])
        elif self.metric == "RMSE":
            return float(metrics[1])
        elif self.metric == "NSE":
            return float(metrics[3])
        elif self.metric == "R2":
            return abs(1 - float(metrics[4]))
        elif self.metric == "KGE":
            return float(metrics[5])
        

    def random_solution(self):
        return (self.sup_lim-self.inf_lim) * np.random.random(self.size) + self.inf_lim
    
    def check_bounds(self, solution):
        return solution.clip(self.inf_lim, self.sup_lim)

# %%
substrates_real = [
    SubstrateReal("Gauss", {"F": 0.0001}),
    SubstrateReal("Cauchy", {"F": 0.01}),
    SubstrateReal("DE/best/2", {"F": 0.7, "Cr":0.7}),
    SubstrateReal("BLXalpha", {"Cr": 0.35}),
    # SubstrateReal("Firefly", {"a": 0.7, "b": 1, "d": 0.95, "g": 10}),
    # SubstrateReal("Perm", {"Cr": 4/7}),
]

params = {
    "popSize": 125,
    "rho": 0.6,
    "Fb": 0.98,
    "Fd": 0.2,
    "Pd": 0.99,
    "k": 3,
    "K": 10,
    "group_subs": False,

    "stop_cond": "ngen",
    "time_limit": 400.0,
    #"Ngen": 1,
    "Ngen": 100,
    "Neval": 3e4,
    "fit_target": 1000,

    "verbose": True,
    "v_timer": 1,

    "dynamic": True,
    "dyn_method": "fitness",
    "dyn_metric": "best",
    "dyn_steps": 500,
    "prob_amp": 0.02
}

# %%
model = 2
target = "NSE"

rscript_name = "exec_optim_semidist.R"

r = robjects.r
r['source'](rscript_name)
get_basin_q = robjects.globalenv['get_basin_q']

basins = pd.read_csv("basins.txt")
#basins.sort_values(by=["order"])
agg_q = {}
basin_params = {}

prev_q = 0
for idx in basins.index:
    basin_code = basins["code"][idx]
    codedown = basins["codedown"][idx]

    prev_q = 0
    if basin_code in agg_q:
        prev_q = agg_q[basin_code]        

    objfunc = HydroProblemSemidist(rscript_name, target, model, basin_code, prev_q)
    c = CRO_SL(objfunc, substrates_real, params)
    
    print(f"Optimizing basin with code {basin_code}.\n\n")

    c.safe_optimize()
    basin_params[basin_code] = c.best_solution()

    if codedown not in agg_q:
        agg_q[codedown] = 0

    agg_q[codedown] += get_basin_q(model, c.best_solution()[0], basin_code, prev_q)
# Out:
# Rows: 4 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (4): code, order, codedown, supha
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 4 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (4): code, order, codedown, supha
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Optimizing basin with code 3001.
#
#
# Time Spent 254.59s:
# 	Generation: 1
# 	Best fitness: 0.486397
# 	Evaluations of fitness: 241
# 	Substrate probability:
# 		Gauss:    0.25
# 		Cauchy:   0.25
# 		DE/best/2:0.25
# 		BLXalpha: 0.25
#
# Time Spent 360.43s:
# 	Generation: 2
# 	Best fitness: 0.535832
# 	Evaluations of fitness: 341
# 	Substrate probability:
# 		Gauss:    0.144851
# 		Cauchy:   0.10304
# 		DE/best/2:0.607115
# 		BLXalpha: 0.144994
#
# Time Spent 462.88s:
# 	Generation: 3
# 	Best fitness: 0.535832
# 	Evaluations of fitness: 438
# 	Substrate probability:
# 		Gauss:    0.016788
# 		Cauchy:   0.164591
# 		DE/best/2:0.764156
# 		BLXalpha: 0.054465
#
# Time Spent 563.59s:
# 	Generation: 4
# 	Best fitness: 0.547037
# 	Evaluations of fitness: 533
# 	Substrate probability:
# 		Gauss:    0.004902
# 		Cauchy:   0.216282
# 		DE/best/2:0.174445
# 		BLXalpha: 0.604371
#
# Time Spent 660.63s:
# 	Generation: 5
# 	Best fitness: 0.619311
# 	Evaluations of fitness: 625
# 	Substrate probability:
# 		Gauss:    0.004902
# 		Cauchy:   0.420107
# 		DE/best/2:0.43011
# 		BLXalpha: 0.144881
#
# Time Spent 761.71s:
# 	Generation: 6
# 	Best fitness: 0.619488
# 	Evaluations of fitness: 721
# 	Substrate probability:
# 		Gauss:    0.004902
# 		Cauchy:   0.038661
# 		DE/best/2:0.885692
# 		BLXalpha: 0.070745
#
# Time Spent 862.86s:
# 	Generation: 7
# 	Best fitness: 0.619488
# 	Evaluations of fitness: 817
# 	Substrate probability:
# 		Gauss:    0.01551
# 		Cauchy:   0.185085
# 		DE/best/2:0.695092
# 		BLXalpha: 0.104314
#
# Time Spent 966.04s:
# 	Generation: 8
# 	Best fitness: 0.623754
# 	Evaluations of fitness: 914
# 	Substrate probability:
# 		Gauss:    0.015392
# 		Cauchy:   0.188642
# 		DE/best/2:0.715055
# 		BLXalpha: 0.080911
#
# Time Spent 1067.93s:
# 	Generation: 9
# 	Best fitness: 0.62823
# 	Evaluations of fitness: 1011
# 	Substrate probability:
# 		Gauss:    0.023595
# 		Cauchy:   0.259346
# 		DE/best/2:0.183655
# 		BLXalpha: 0.533404
#
# Time Spent 1167.69s:
# 	Generation: 10
# 	Best fitness: 0.631949
# 	Evaluations of fitness: 1106
# 	Substrate probability:
# 		Gauss:    0.013872
# 		Cauchy:   0.522964
# 		DE/best/2:0.181766
# 		BLXalpha: 0.281398
#
# Time Spent 1261.39s:
# 	Generation: 11
# 	Best fitness: 0.631949
# 	Evaluations of fitness: 1195
# 	Substrate probability:
# 		Gauss:    0.081271
# 		Cauchy:   0.221973
# 		DE/best/2:0.513593
# 		BLXalpha: 0.183163
#
# Time Spent 1360.55s:
# 	Generation: 12
# 	Best fitness: 0.63965
# 	Evaluations of fitness: 1289
# 	Substrate probability:
# 		Gauss:    0.341462
# 		Cauchy:   0.242168
# 		DE/best/2:0.287782
# 		BLXalpha: 0.128589
#
# Time Spent 1460.72s:
# 	Generation: 13
# 	Best fitness: 0.63988
# 	Evaluations of fitness: 1384
# 	Substrate probability:
# 		Gauss:    0.226884
# 		Cauchy:   0.239659
# 		DE/best/2:0.284207
# 		BLXalpha: 0.24925
#
# Time Spent 1561.18s:
# 	Generation: 14
# 	Best fitness: 0.645525
# 	Evaluations of fitness: 1479
# 	Substrate probability:
# 		Gauss:    0.268517
# 		Cauchy:   0.22286
# 		DE/best/2:0.31453
# 		BLXalpha: 0.194093
#
# Time Spent 1662.2s:
# 	Generation: 15
# 	Best fitness: 0.645525
# 	Evaluations of fitness: 1575
# 	Substrate probability:
# 		Gauss:    0.239485
# 		Cauchy:   0.237683
# 		DE/best/2:0.313138
# 		BLXalpha: 0.209694
#
# Time Spent 1760.06s:
# 	Generation: 16
# 	Best fitness: 0.654045
# 	Evaluations of fitness: 1668
# 	Substrate probability:
# 		Gauss:    0.241379
# 		Cauchy:   0.214181
# 		DE/best/2:0.312862
# 		BLXalpha: 0.231578
#
# Time Spent 1858.44s:
# 	Generation: 17
# 	Best fitness: 0.654045
# 	Evaluations of fitness: 1761
# 	Substrate probability:
# 		Gauss:    0.267115
# 		Cauchy:   0.208237
# 		DE/best/2:0.315442
# 		BLXalpha: 0.209206
#
# Time Spent 1956.24s:
# 	Generation: 18
# 	Best fitness: 0.655493
# 	Evaluations of fitness: 1853
# 	Substrate probability:
# 		Gauss:    0.237571
# 		Cauchy:   0.205063
# 		DE/best/2:0.278842
# 		BLXalpha: 0.278525
#
# Time Spent 2058.1s:
# 	Generation: 19
# 	Best fitness: 0.657259
# 	Evaluations of fitness: 1950
# 	Substrate probability:
# 		Gauss:    0.258458
# 		Cauchy:   0.254467
# 		DE/best/2:0.265788
# 		BLXalpha: 0.221288
#
# Time Spent 2159.11s:
# 	Generation: 20
# 	Best fitness: 0.658911
# 	Evaluations of fitness: 2046
# 	Substrate probability:
# 		Gauss:    0.252136
# 		Cauchy:   0.24561
# 		DE/best/2:0.268174
# 		BLXalpha: 0.23408
#
# Time Spent 2260.05s:
# 	Generation: 21
# 	Best fitness: 0.658911
# 	Evaluations of fitness: 2142
# 	Substrate probability:
# 		Gauss:    0.253603
# 		Cauchy:   0.247423
# 		DE/best/2:0.276005
# 		BLXalpha: 0.22297
#
# Time Spent 2364.03s:
# 	Generation: 22
# 	Best fitness: 0.659528
# 	Evaluations of fitness: 2241
# 	Substrate probability:
# 		Gauss:    0.25116
# 		Cauchy:   0.252358
# 		DE/best/2:0.251347
# 		BLXalpha: 0.245134
#
# Time Spent 2464.44s:
# 	Generation: 23
# 	Best fitness: 0.660583
# 	Evaluations of fitness: 2337
# 	Substrate probability:
# 		Gauss:    0.236972
# 		Cauchy:   0.260821
# 		DE/best/2:0.255076
# 		BLXalpha: 0.247131
#
# Time Spent 2563.89s:
# 	Generation: 24
# 	Best fitness: 0.665227
# 	Evaluations of fitness: 2432
# 	Substrate probability:
# 		Gauss:    0.247762
# 		Cauchy:   0.245928
# 		DE/best/2:0.263557
# 		BLXalpha: 0.242752
#
# Time Spent 2665.21s:
# 	Generation: 25
# 	Best fitness: 0.665227
# 	Evaluations of fitness: 2528
# 	Substrate probability:
# 		Gauss:    0.244887
# 		Cauchy:   0.241269
# 		DE/best/2:0.267369
# 		BLXalpha: 0.246475
#
# Time Spent 2766.03s:
# 	Generation: 26
# 	Best fitness: 0.665227
# 	Evaluations of fitness: 2624
# 	Substrate probability:
# 		Gauss:    0.240774
# 		Cauchy:   0.254814
# 		DE/best/2:0.250888
# 		BLXalpha: 0.253524
#
# Time Spent 2867.95s:
# 	Generation: 27
# 	Best fitness: 0.665227
# 	Evaluations of fitness: 2720
# 	Substrate probability:
# 		Gauss:    0.253349
# 		Cauchy:   0.237368
# 		DE/best/2:0.250409
# 		BLXalpha: 0.258874
#
# Time Spent 2969.0s:
# 	Generation: 28
# 	Best fitness: 0.665949
# 	Evaluations of fitness: 2816
# 	Substrate probability:
# 		Gauss:    0.249795
# 		Cauchy:   0.245664
# 		DE/best/2:0.251287
# 		BLXalpha: 0.253255
#
# Time Spent 3072.29s:
# 	Generation: 29
# 	Best fitness: 0.666305
# 	Evaluations of fitness: 2913
# 	Substrate probability:
# 		Gauss:    0.248615
# 		Cauchy:   0.241592
# 		DE/best/2:0.257606
# 		BLXalpha: 0.252187
#
# Time Spent 3177.16s:
# 	Generation: 30
# 	Best fitness: 0.666305
# 	Evaluations of fitness: 3012
# 	Substrate probability:
# 		Gauss:    0.251681
# 		Cauchy:   0.24515
# 		DE/best/2:0.253326
# 		BLXalpha: 0.249844
#
# Time Spent 3278.45s:
# 	Generation: 31
# 	Best fitness: 0.666305
# 	Evaluations of fitness: 3108
# 	Substrate probability:
# 		Gauss:    0.252765
# 		Cauchy:   0.239889
# 		DE/best/2:0.254342
# 		BLXalpha: 0.253003
#
# Time Spent 3381.12s:
# 	Generation: 32
# 	Best fitness: 0.66669
# 	Evaluations of fitness: 3205
# 	Substrate probability:
# 		Gauss:    0.253433
# 		Cauchy:   0.245244
# 		DE/best/2:0.24809
# 		BLXalpha: 0.253233
#
# Time Spent 3480.75s:
# 	Generation: 33
# 	Best fitness: 0.666691
# 	Evaluations of fitness: 3299
# 	Substrate probability:
# 		Gauss:    0.251158
# 		Cauchy:   0.253136
# 		DE/best/2:0.246914
# 		BLXalpha: 0.248793
#
# Time Spent 3583.23s:
# 	Generation: 34
# 	Best fitness: 0.666691
# 	Evaluations of fitness: 3396
# 	Substrate probability:
# 		Gauss:    0.252287
# 		Cauchy:   0.247881
# 		DE/best/2:0.249346
# 		BLXalpha: 0.250485
#
# Time Spent 3682.4s:
# 	Generation: 35
# 	Best fitness: 0.666696
# 	Evaluations of fitness: 3490
# 	Substrate probability:
# 		Gauss:    0.249594
# 		Cauchy:   0.25026
# 		DE/best/2:0.251809
# 		BLXalpha: 0.248337
#
# Time Spent 3784.63s:
# 	Generation: 36
# 	Best fitness: 0.666696
# 	Evaluations of fitness: 3587
# 	Substrate probability:
# 		Gauss:    0.25188
# 		Cauchy:   0.247937
# 		DE/best/2:0.249421
# 		BLXalpha: 0.250762
#
# Time Spent 3885.7s:
# 	Generation: 37
# 	Best fitness: 0.666783
# 	Evaluations of fitness: 3683
# 	Substrate probability:
# 		Gauss:    0.250711
# 		Cauchy:   0.249272
# 		DE/best/2:0.249281
# 		BLXalpha: 0.250735
#
# Time Spent 3986.91s:
# 	Generation: 38
# 	Best fitness: 0.666783
# 	Evaluations of fitness: 3779
# 	Substrate probability:
# 		Gauss:    0.249474
# 		Cauchy:   0.24847
# 		DE/best/2:0.251777
# 		BLXalpha: 0.25028
#
# Time Spent 4087.08s:
# 	Generation: 39
# 	Best fitness: 0.666942
# 	Evaluations of fitness: 3874
# 	Substrate probability:
# 		Gauss:    0.250651
# 		Cauchy:   0.248881
# 		DE/best/2:0.250759
# 		BLXalpha: 0.249708
#
# Time Spent 4189.51s:
# 	Generation: 40
# 	Best fitness: 0.667013
# 	Evaluations of fitness: 3971
# 	Substrate probability:
# 		Gauss:    0.250184
# 		Cauchy:   0.24746
# 		DE/best/2:0.251129
# 		BLXalpha: 0.251228
#
# Time Spent 4290.92s:
# 	Generation: 41
# 	Best fitness: 0.667013
# 	Evaluations of fitness: 4067
# 	Substrate probability:
# 		Gauss:    0.249553
# 		Cauchy:   0.249754
# 		DE/best/2:0.251059
# 		BLXalpha: 0.249633
#
# Time Spent 4392.53s:
# 	Generation: 42
# 	Best fitness: 0.667042
# 	Evaluations of fitness: 4163
# 	Substrate probability:
# 		Gauss:    0.250237
# 		Cauchy:   0.249039
# 		DE/best/2:0.250204
# 		BLXalpha: 0.250519
#
# Time Spent 4492.63s:
# 	Generation: 43
# 	Best fitness: 0.667441
# 	Evaluations of fitness: 4258
# 	Substrate probability:
# 		Gauss:    0.250055
# 		Cauchy:   0.24926
# 		DE/best/2:0.251013
# 		BLXalpha: 0.249671
#
# Time Spent 4595.67s:
# 	Generation: 44
# 	Best fitness: 0.670198
# 	Evaluations of fitness: 4356
# 	Substrate probability:
# 		Gauss:    0.249637
# 		Cauchy:   0.248773
# 		DE/best/2:0.252186
# 		BLXalpha: 0.249403
#
# Time Spent 4698.84s:
# 	Generation: 45
# 	Best fitness: 0.670663
# 	Evaluations of fitness: 4454
# 	Substrate probability:
# 		Gauss:    0.246318
# 		Cauchy:   0.24514
# 		DE/best/2:0.261361
# 		BLXalpha: 0.247181
#
# Time Spent 4802.05s:
# 	Generation: 46
# 	Best fitness: 0.670663
# 	Evaluations of fitness: 4552
# 	Substrate probability:
# 		Gauss:    0.248891
# 		Cauchy:   0.243707
# 		DE/best/2:0.262007
# 		BLXalpha: 0.245395
#
# Time Spent 4903.13s:
# 	Generation: 47
# 	Best fitness: 0.670663
# 	Evaluations of fitness: 4648
# 	Substrate probability:
# 		Gauss:    0.248456
# 		Cauchy:   0.244213
# 		DE/best/2:0.254545
# 		BLXalpha: 0.252786
#
# Time Spent 5003.2s:
# 	Generation: 48
# 	Best fitness: 0.670663
# 	Evaluations of fitness: 4743
# 	Substrate probability:
# 		Gauss:    0.251316
# 		Cauchy:   0.241724
# 		DE/best/2:0.24956
# 		BLXalpha: 0.2574
#
# Time Spent 5101.29s:
# 	Generation: 49
# 	Best fitness: 0.670663
# 	Evaluations of fitness: 4836
# 	Substrate probability:
# 		Gauss:    0.25444
# 		Cauchy:   0.243512
# 		DE/best/2:0.24655
# 		BLXalpha: 0.255497
#
# Time Spent 5200.41s:
# 	Generation: 50
# 	Best fitness: 0.670663
# 	Evaluations of fitness: 4930
# 	Substrate probability:
# 		Gauss:    0.252114
# 		Cauchy:   0.247354
# 		DE/best/2:0.248793
# 		BLXalpha: 0.251738
#
# Time Spent 5302.13s:
# 	Generation: 51
# 	Best fitness: 0.670776
# 	Evaluations of fitness: 5026
# 	Substrate probability:
# 		Gauss:    0.253533
# 		Cauchy:   0.248092
# 		DE/best/2:0.245645
# 		BLXalpha: 0.252729
#
# Time Spent 5402.28s:
# 	Generation: 52
# 	Best fitness: 0.671134
# 	Evaluations of fitness: 5121
# 	Substrate probability:
# 		Gauss:    0.25021
# 		Cauchy:   0.248435
# 		DE/best/2:0.251187
# 		BLXalpha: 0.250168
#
# Time Spent 5502.43s:
# 	Generation: 53
# 	Best fitness: 0.671451
# 	Evaluations of fitness: 5216
# 	Substrate probability:
# 		Gauss:    0.250177
# 		Cauchy:   0.247953
# 		DE/best/2:0.252369
# 		BLXalpha: 0.249502
#
# Time Spent 5602.74s:
# 	Generation: 54
# 	Best fitness: 0.671451
# 	Evaluations of fitness: 5311
# 	Substrate probability:
# 		Gauss:    0.248458
# 		Cauchy:   0.247959
# 		DE/best/2:0.251031
# 		BLXalpha: 0.252551
#
# Time Spent 5707.26s:
# 	Generation: 55
# 	Best fitness: 0.671961
# 	Evaluations of fitness: 5410
# 	Substrate probability:
# 		Gauss:    0.251204
# 		Cauchy:   0.245778
# 		DE/best/2:0.250876
# 		BLXalpha: 0.252142
#
# Time Spent 5808.69s:
# 	Generation: 56
# 	Best fitness: 0.672015
# 	Evaluations of fitness: 5506
# 	Substrate probability:
# 		Gauss:    0.249199
# 		Cauchy:   0.249106
# 		DE/best/2:0.25259
# 		BLXalpha: 0.249106
#
# Time Spent 5909.02s:
# 	Generation: 57
# 	Best fitness: 0.672049
# 	Evaluations of fitness: 5600
# 	Substrate probability:
# 		Gauss:    0.248636
# 		Cauchy:   0.248317
# 		DE/best/2:0.252235
# 		BLXalpha: 0.250812
#
# Time Spent 6008.24s:
# 	Generation: 58
# 	Best fitness: 0.672101
# 	Evaluations of fitness: 5694
# 	Substrate probability:
# 		Gauss:    0.249895
# 		Cauchy:   0.245743
# 		DE/best/2:0.251458
# 		BLXalpha: 0.252904
#
# Time Spent 6109.18s:
# 	Generation: 59
# 	Best fitness: 0.67276
# 	Evaluations of fitness: 5789
# 	Substrate probability:
# 		Gauss:    0.249269
# 		Cauchy:   0.249961
# 		DE/best/2:0.2497
# 		BLXalpha: 0.25107
#
# Time Spent 6211.01s:
# 	Generation: 60
# 	Best fitness: 0.67276
# 	Evaluations of fitness: 5885
# 	Substrate probability:
# 		Gauss:    0.248672
# 		Cauchy:   0.249483
# 		DE/best/2:0.253034
# 		BLXalpha: 0.248811
#
# Time Spent 6312.44s:
# 	Generation: 61
# 	Best fitness: 0.672984
# 	Evaluations of fitness: 5980
# 	Substrate probability:
# 		Gauss:    0.253674
# 		Cauchy:   0.242291
# 		DE/best/2:0.252695
# 		BLXalpha: 0.25134
#
# Time Spent 6414.42s:
# 	Generation: 62
# 	Best fitness: 0.672984
# 	Evaluations of fitness: 6076
# 	Substrate probability:
# 		Gauss:    0.252137
# 		Cauchy:   0.244738
# 		DE/best/2:0.253213
# 		BLXalpha: 0.249911
#
# Time Spent 6513.34s:
# 	Generation: 63
# 	Best fitness: 0.673592
# 	Evaluations of fitness: 6169
# 	Substrate probability:
# 		Gauss:    0.253347
# 		Cauchy:   0.245469
# 		DE/best/2:0.250779
# 		BLXalpha: 0.250406
#
# Time Spent 6616.45s:
# 	Generation: 64
# 	Best fitness: 0.674868
# 	Evaluations of fitness: 6264
# 	Substrate probability:
# 		Gauss:    0.251165
# 		Cauchy:   0.244057
# 		DE/best/2:0.253995
# 		BLXalpha: 0.250783
#
# Time Spent 6717.48s:
# 	Generation: 65
# 	Best fitness: 0.674886
# 	Evaluations of fitness: 6357
# 	Substrate probability:
# 		Gauss:    0.250635
# 		Cauchy:   0.245265
# 		DE/best/2:0.256594
# 		BLXalpha: 0.247506
#
# Time Spent 6822.19s:
# 	Generation: 66
# 	Best fitness: 0.675247
# 	Evaluations of fitness: 6454
# 	Substrate probability:
# 		Gauss:    0.250183
# 		Cauchy:   0.245437
# 		DE/best/2:0.256144
# 		BLXalpha: 0.248236
#
# Time Spent 6923.77s:
# 	Generation: 67
# 	Best fitness: 0.675247
# 	Evaluations of fitness: 6549
# 	Substrate probability:
# 		Gauss:    0.253502
# 		Cauchy:   0.242918
# 		DE/best/2:0.255228
# 		BLXalpha: 0.248352
#
# Time Spent 7026.43s:
# 	Generation: 68
# 	Best fitness: 0.675247
# 	Evaluations of fitness: 6645
# 	Substrate probability:
# 		Gauss:    0.251983
# 		Cauchy:   0.245068
# 		DE/best/2:0.251651
# 		BLXalpha: 0.251297
#
# Time Spent 7129.19s:
# 	Generation: 69
# 	Best fitness: 0.6757
# 	Evaluations of fitness: 6741
# 	Substrate probability:
# 		Gauss:    0.250379
# 		Cauchy:   0.247649
# 		DE/best/2:0.251383
# 		BLXalpha: 0.250588
#
# Time Spent 7227.56s:
# 	Generation: 70
# 	Best fitness: 0.6757
# 	Evaluations of fitness: 6833
# 	Substrate probability:
# 		Gauss:    0.24934
# 		Cauchy:   0.251738
# 		DE/best/2:0.248801
# 		BLXalpha: 0.250121
#
# Time Spent 7322.06s:
# 	Generation: 71
# 	Best fitness: 0.6757
# 	Evaluations of fitness: 6921
# 	Substrate probability:
# 		Gauss:    0.250077
# 		Cauchy:   0.246889
# 		DE/best/2:0.251764
# 		BLXalpha: 0.25127
#
# Time Spent 7418.01s:
# 	Generation: 72
# 	Best fitness: 0.6758
# 	Evaluations of fitness: 7010
# 	Substrate probability:
# 		Gauss:    0.25108
# 		Cauchy:   0.247418
# 		DE/best/2:0.25083
# 		BLXalpha: 0.250672
#
# Time Spent 7517.3s:
# 	Generation: 73
# 	Best fitness: 0.675983
# 	Evaluations of fitness: 7103
# 	Substrate probability:
# 		Gauss:    0.251107
# 		Cauchy:   0.246987
# 		DE/best/2:0.251619
# 		BLXalpha: 0.250286
#
# Time Spent 7619.94s:
# 	Generation: 74
# 	Best fitness: 0.675998
# 	Evaluations of fitness: 7199
# 	Substrate probability:
# 		Gauss:    0.250131
# 		Cauchy:   0.248815
# 		DE/best/2:0.250979
# 		BLXalpha: 0.250075
#
# Time Spent 7721.01s:
# 	Generation: 75
# 	Best fitness: 0.676008
# 	Evaluations of fitness: 7294
# 	Substrate probability:
# 		Gauss:    0.249784
# 		Cauchy:   0.248903
# 		DE/best/2:0.251081
# 		BLXalpha: 0.250232
#
# Time Spent 7823.76s:
# 	Generation: 76
# 	Best fitness: 0.676008
# 	Evaluations of fitness: 7390
# 	Substrate probability:
# 		Gauss:    0.250694
# 		Cauchy:   0.247235
# 		DE/best/2:0.251395
# 		BLXalpha: 0.250675
#
# Time Spent 7926.61s:
# 	Generation: 77
# 	Best fitness: 0.676008
# 	Evaluations of fitness: 7486
# 	Substrate probability:
# 		Gauss:    0.25028
# 		Cauchy:   0.248978
# 		DE/best/2:0.250378
# 		BLXalpha: 0.250364
#
# Time Spent 8028.83s:
# 	Generation: 78
# 	Best fitness: 0.676008
# 	Evaluations of fitness: 7582
# 	Substrate probability:
# 		Gauss:    0.250041
# 		Cauchy:   0.248878
# 		DE/best/2:0.250531
# 		BLXalpha: 0.25055
#
# Time Spent 8129.98s:
# 	Generation: 79
# 	Best fitness: 0.67601
# 	Evaluations of fitness: 7678
# 	Substrate probability:
# 		Gauss:    0.250327
# 		Cauchy:   0.248712
# 		DE/best/2:0.250304
# 		BLXalpha: 0.250656
#
# Time Spent 8225.89s:
# 	Generation: 80
# 	Best fitness: 0.67601
# 	Evaluations of fitness: 7769
# 	Substrate probability:
# 		Gauss:    0.250073
# 		Cauchy:   0.249454
# 		DE/best/2:0.25041
# 		BLXalpha: 0.250063
#
# Time Spent 8324.68s:
# 	Generation: 81
# 	Best fitness: 0.67601
# 	Evaluations of fitness: 7863
# 	Substrate probability:
# 		Gauss:    0.250562
# 		Cauchy:   0.248624
# 		DE/best/2:0.250525
# 		BLXalpha: 0.250289
#
# Time Spent 8427.03s:
# 	Generation: 82
# 	Best fitness: 0.676053
# 	Evaluations of fitness: 7960
# 	Substrate probability:
# 		Gauss:    0.250033
# 		Cauchy:   0.249728
# 		DE/best/2:0.250103
# 		BLXalpha: 0.250135
#
# Time Spent 8526.25s:
# 	Generation: 83
# 	Best fitness: 0.676073
# 	Evaluations of fitness: 8054
# 	Substrate probability:
# 		Gauss:    0.250869
# 		Cauchy:   0.246956
# 		DE/best/2:0.251148
# 		BLXalpha: 0.251027
#
# Time Spent 8627.36s:
# 	Generation: 84
# 	Best fitness: 0.676073
# 	Evaluations of fitness: 8150
# 	Substrate probability:
# 		Gauss:    0.250336
# 		Cauchy:   0.248593
# 		DE/best/2:0.250624
# 		BLXalpha: 0.250448
#
# Time Spent 8731.92s:
# 	Generation: 85
# 	Best fitness: 0.676073
# 	Evaluations of fitness: 8249
# 	Substrate probability:
# 		Gauss:    0.250241
# 		Cauchy:   0.249235
# 		DE/best/2:0.250218
# 		BLXalpha: 0.250306
#
# Time Spent 8837.22s:
# 	Generation: 86
# 	Best fitness: 0.676073
# 	Evaluations of fitness: 8347
# 	Substrate probability:
# 		Gauss:    0.250257
# 		Cauchy:   0.249112
# 		DE/best/2:0.250336
# 		BLXalpha: 0.250294
#
# Time Spent 8940.13s:
# 	Generation: 87
# 	Best fitness: 0.676085
# 	Evaluations of fitness: 8444
# 	Substrate probability:
# 		Gauss:    0.250802
# 		Cauchy:   0.247475
# 		DE/best/2:0.25088
# 		BLXalpha: 0.250843
#
# Time Spent 9043.9s:
# 	Generation: 88
# 	Best fitness: 0.676085
# 	Evaluations of fitness: 8542
# 	Substrate probability:
# 		Gauss:    0.250042
# 		Cauchy:   0.249672
# 		DE/best/2:0.250194
# 		BLXalpha: 0.250092
#
# Time Spent 9146.09s:
# 	Generation: 89
# 	Best fitness: 0.676085
# 	Evaluations of fitness: 8638
# 	Substrate probability:
# 		Gauss:    0.250475
# 		Cauchy:   0.248528
# 		DE/best/2:0.250498
# 		BLXalpha: 0.250498
#
# Time Spent 9249.58s:
# 	Generation: 90
# 	Best fitness: 0.676085
# 	Evaluations of fitness: 8735
# 	Substrate probability:
# 		Gauss:    0.250375
# 		Cauchy:   0.248815
# 		DE/best/2:0.250407
# 		BLXalpha: 0.250403
#
# Time Spent 9352.35s:
# 	Generation: 91
# 	Best fitness: 0.676085
# 	Evaluations of fitness: 8831
# 	Substrate probability:
# 		Gauss:    0.250399
# 		Cauchy:   0.248839
# 		DE/best/2:0.250381
# 		BLXalpha: 0.250381
#
# Time Spent 9452.21s:
# 	Generation: 92
# 	Best fitness: 0.676086
# 	Evaluations of fitness: 8925
# 	Substrate probability:
# 		Gauss:    0.250697
# 		Cauchy:   0.247876
# 		DE/best/2:0.250716
# 		BLXalpha: 0.250711
#
# Time Spent 9550.94s:
# 	Generation: 93
# 	Best fitness: 0.676086
# 	Evaluations of fitness: 9019
# 	Substrate probability:
# 		Gauss:    0.251192
# 		Cauchy:   0.246456
# 		DE/best/2:0.25115
# 		BLXalpha: 0.251201
#
# Time Spent 9651.37s:
# 	Generation: 94
# 	Best fitness: 0.676086
# 	Evaluations of fitness: 9115
# 	Substrate probability:
# 		Gauss:    0.250052
# 		Cauchy:   0.249821
# 		DE/best/2:0.250057
# 		BLXalpha: 0.25007
#
# Time Spent 9751.16s:
# 	Generation: 95
# 	Best fitness: 0.676087
# 	Evaluations of fitness: 9209
# 	Substrate probability:
# 		Gauss:    0.250262
# 		Cauchy:   0.249195
# 		DE/best/2:0.250267
# 		BLXalpha: 0.250276
#
# Time Spent 9854.34s:
# 	Generation: 96
# 	Best fitness: 0.676087
# 	Evaluations of fitness: 9306
# 	Substrate probability:
# 		Gauss:    0.250125
# 		Cauchy:   0.249617
# 		DE/best/2:0.250134
# 		BLXalpha: 0.250125
#
# Time Spent 9957.8s:
# 	Generation: 97
# 	Best fitness: 0.676087
# 	Evaluations of fitness: 9403
# 	Substrate probability:
# 		Gauss:    0.250181
# 		Cauchy:   0.249456
# 		DE/best/2:0.250181
# 		BLXalpha: 0.250181
#
# Time Spent 10059.61s:
# 	Generation: 98
# 	Best fitness: 0.676089
# 	Evaluations of fitness: 9500
# 	Substrate probability:
# 		Gauss:    0.250226
# 		Cauchy:   0.249316
# 		DE/best/2:0.250231
# 		BLXalpha: 0.250226
#
# Time Spent 10159.74s:
# 	Generation: 99
# 	Best fitness: 0.676089
# 	Evaluations of fitness: 9596
# 	Substrate probability:
# 		Gauss:    0.250302
# 		Cauchy:   0.249116
# 		DE/best/2:0.250289
# 		BLXalpha: 0.250293
#
# Time Spent 10262.25s:
# 	Generation: 100
# 	Best fitness: 0.676089
# 	Evaluations of fitness: 9694
# 	Substrate probability:
# 		Gauss:    0.250111
# 		Cauchy:   0.249653
# 		DE/best/2:0.250116
# 		BLXalpha: 0.25012
#
# Rows: 4 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (4): code, order, codedown, supha
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Optimizing basin with code 3030.
#
#
# Time Spent 275.49s:
# 	Generation: 1
# 	Best fitness: 0.273471
# 	Evaluations of fitness: 261
# 	Substrate probability:
# 		Gauss:    0.25
# 		Cauchy:   0.25
# 		DE/best/2:0.25
# 		BLXalpha: 0.25
#
# Time Spent 376.71s:
# 	Generation: 2
# 	Best fitness: 0.348546
# 	Evaluations of fitness: 358
# 	Substrate probability:
# 		Gauss:    0.009694
# 		Cauchy:   0.004902
# 		DE/best/2:0.95362
# 		BLXalpha: 0.031784
#
# Time Spent 479.46s:
# 	Generation: 3
# 	Best fitness: 0.348546
# 	Evaluations of fitness: 456
# 	Substrate probability:
# 		Gauss:    0.176546
# 		Cauchy:   0.176546
# 		DE/best/2:0.642005
# 		BLXalpha: 0.004902
#
# Time Spent 579.15s:
# 	Generation: 4
# 	Best fitness: 0.348565
# 	Evaluations of fitness: 549
# 	Substrate probability:
# 		Gauss:    0.719968
# 		Cauchy:   0.005229
# 		DE/best/2:0.269901
# 		BLXalpha: 0.004902
#
# Time Spent 678.2s:
# 	Generation: 5
# 	Best fitness: 0.354712
# 	Evaluations of fitness: 643
# 	Substrate probability:
# 		Gauss:    0.49474
# 		Cauchy:   0.004903
# 		DE/best/2:0.495455
# 		BLXalpha: 0.004902
#
# Time Spent 780.58s:
# 	Generation: 6
# 	Best fitness: 0.354712
# 	Evaluations of fitness: 739
# 	Substrate probability:
# 		Gauss:    0.3719
# 		Cauchy:   0.004902
# 		DE/best/2:0.499032
# 		BLXalpha: 0.124166
#
# Time Spent 882.32s:
# 	Generation: 7
# 	Best fitness: 0.370856
# 	Evaluations of fitness: 835
# 	Substrate probability:
# 		Gauss:    0.444906
# 		Cauchy:   0.004902
# 		DE/best/2:0.337022
# 		BLXalpha: 0.21317
#
# Time Spent 984.3s:
# 	Generation: 8
# 	Best fitness: 0.384704
# 	Evaluations of fitness: 931
# 	Substrate probability:
# 		Gauss:    0.254999
# 		Cauchy:   0.005266
# 		DE/best/2:0.51618
# 		BLXalpha: 0.223555
#
# Time Spent 1082.57s:
# 	Generation: 9
# 	Best fitness: 0.387874
# 	Evaluations of fitness: 1023
# 	Substrate probability:
# 		Gauss:    0.182228
# 		Cauchy:   0.004902
# 		DE/best/2:0.667056
# 		BLXalpha: 0.145814
#
# Time Spent 1184.61s:
# 	Generation: 10
# 	Best fitness: 0.394888
# 	Evaluations of fitness: 1119
# 	Substrate probability:
# 		Gauss:    0.364887
# 		Cauchy:   0.116727
# 		DE/best/2:0.408609
# 		BLXalpha: 0.109776
#
# Time Spent 1284.57s:
# 	Generation: 11
# 	Best fitness: 0.405698
# 	Evaluations of fitness: 1214
# 	Substrate probability:
# 		Gauss:    0.2927
# 		Cauchy:   0.163701
# 		DE/best/2:0.367818
# 		BLXalpha: 0.175781
#
# Time Spent 1385.53s:
# 	Generation: 12
# 	Best fitness: 0.405698
# 	Evaluations of fitness: 1309
# 	Substrate probability:
# 		Gauss:    0.243397
# 		Cauchy:   0.138272
# 		DE/best/2:0.453322
# 		BLXalpha: 0.165008
#
# Time Spent 1487.5s:
# 	Generation: 13
# 	Best fitness: 0.405698
# 	Evaluations of fitness: 1405
# 	Substrate probability:
# 		Gauss:    0.324615
# 		Cauchy:   0.267322
# 		DE/best/2:0.181814
# 		BLXalpha: 0.226249
#
# Time Spent 1588.38s:
# 	Generation: 14
# 	Best fitness: 0.414392
# 	Evaluations of fitness: 1500
# 	Substrate probability:
# 		Gauss:    0.308262
# 		Cauchy:   0.231452
# 		DE/best/2:0.198141
# 		BLXalpha: 0.262144
#
# Time Spent 1690.52s:
# 	Generation: 15
# 	Best fitness: 0.414392
# 	Evaluations of fitness: 1596
# 	Substrate probability:
# 		Gauss:    0.286088
# 		Cauchy:   0.374603
# 		DE/best/2:0.156319
# 		BLXalpha: 0.18299
#
# Time Spent 1792.63s:
# 	Generation: 16
# 	Best fitness: 0.414392
# 	Evaluations of fitness: 1692
# 	Substrate probability:
# 		Gauss:    0.283738
# 		Cauchy:   0.370889
# 		DE/best/2:0.117843
# 		BLXalpha: 0.227529
#
# Time Spent 1889.68s:
# 	Generation: 17
# 	Best fitness: 0.414392
# 	Evaluations of fitness: 1784
# 	Substrate probability:
# 		Gauss:    0.231918
# 		Cauchy:   0.247887
# 		DE/best/2:0.278546
# 		BLXalpha: 0.24165
#
# Time Spent 2042.36s:
# 	Generation: 18
# 	Best fitness: 0.414392
# 	Evaluations of fitness: 1880
# 	Substrate probability:
# 		Gauss:    0.248858
# 		Cauchy:   0.288694
# 		DE/best/2:0.19238
# 		BLXalpha: 0.270068
#
# Time Spent 2327.71s:
# 	Generation: 19
# 	Best fitness: 0.414392
# 	Evaluations of fitness: 1978
# 	Substrate probability:
# 		Gauss:    0.279951
# 		Cauchy:   0.251225
# 		DE/best/2:0.172747
# 		BLXalpha: 0.296077
#
# Time Spent 2617.24s:
# 	Generation: 20
# 	Best fitness: 0.414392
# 	Evaluations of fitness: 2076
# 	Substrate probability:
# 		Gauss:    0.276461
# 		Cauchy:   0.259656
# 		DE/best/2:0.210113
# 		BLXalpha: 0.253771
#
# Time Spent 2905.34s:
# 	Generation: 21
# 	Best fitness: 0.414392
# 	Evaluations of fitness: 2173
# 	Substrate probability:
# 		Gauss:    0.245733
# 		Cauchy:   0.262723
# 		DE/best/2:0.248913
# 		BLXalpha: 0.242631
#
# Time Spent 3186.46s:
# 	Generation: 22
# 	Best fitness: 0.415528
# 	Evaluations of fitness: 2269
# 	Substrate probability:
# 		Gauss:    0.259451
# 		Cauchy:   0.258323
# 		DE/best/2:0.226594
# 		BLXalpha: 0.255632
#
# Time Spent 3458.8s:
# 	Generation: 23
# 	Best fitness: 0.42027
# 	Evaluations of fitness: 2363
# 	Substrate probability:
# 		Gauss:    0.243166
# 		Cauchy:   0.227846
# 		DE/best/2:0.269433
# 		BLXalpha: 0.259555
#
# Time Spent 3736.53s:
# 	Generation: 24
# 	Best fitness: 0.422872
# 	Evaluations of fitness: 2457
# 	Substrate probability:
# 		Gauss:    0.246345
# 		Cauchy:   0.204601
# 		DE/best/2:0.29788
# 		BLXalpha: 0.251173
#
# Time Spent 4009.35s:
# 	Generation: 25
# 	Best fitness: 0.430565
# 	Evaluations of fitness: 2551
# 	Substrate probability:
# 		Gauss:    0.2654
# 		Cauchy:   0.220137
# 		DE/best/2:0.285769
# 		BLXalpha: 0.228695
#
# Time Spent 4296.37s:
# 	Generation: 26
# 	Best fitness: 0.430691
# 	Evaluations of fitness: 2646
# 	Substrate probability:
# 		Gauss:    0.215418
# 		Cauchy:   0.22785
# 		DE/best/2:0.336745
# 		BLXalpha: 0.219987
#
# Time Spent 4591.81s:
# 	Generation: 27
# 	Best fitness: 0.430691
# 	Evaluations of fitness: 2742
# 	Substrate probability:
# 		Gauss:    0.283213
# 		Cauchy:   0.252982
# 		DE/best/2:0.257224
# 		BLXalpha: 0.206581
#
# Time Spent 4867.81s:
# 	Generation: 28
# 	Best fitness: 0.430886
# 	Evaluations of fitness: 2838
# 	Substrate probability:
# 		Gauss:    0.289034
# 		Cauchy:   0.20181
# 		DE/best/2:0.229447
# 		BLXalpha: 0.279709
#
# Time Spent 5143.31s:
# 	Generation: 29
# 	Best fitness: 0.431138
# 	Evaluations of fitness: 2933
# 	Substrate probability:
# 		Gauss:    0.262823
# 		Cauchy:   0.216053
# 		DE/best/2:0.233664
# 		BLXalpha: 0.287459
#
# Time Spent 5443.41s:
# 	Generation: 30
# 	Best fitness: 0.433901
# 	Evaluations of fitness: 3027
# 	Substrate probability:
# 		Gauss:    0.252273
# 		Cauchy:   0.218217
# 		DE/best/2:0.252664
# 		BLXalpha: 0.276845
#
# Time Spent 5756.93s:
# 	Generation: 31
# 	Best fitness: 0.43568
# 	Evaluations of fitness: 3125
# 	Substrate probability:
# 		Gauss:    0.252822
# 		Cauchy:   0.203592
# 		DE/best/2:0.264057
# 		BLXalpha: 0.279529
#
# Time Spent 6052.1s:
# 	Generation: 32
# 	Best fitness: 0.439524
# 	Evaluations of fitness: 3221
# 	Substrate probability:
# 		Gauss:    0.245939
# 		Cauchy:   0.186811
# 		DE/best/2:0.299166
# 		BLXalpha: 0.268084
#
# Time Spent 6351.31s:
# 	Generation: 33
# 	Best fitness: 0.442222
# 	Evaluations of fitness: 3315
# 	Substrate probability:
# 		Gauss:    0.2396
# 		Cauchy:   0.193668
# 		DE/best/2:0.297659
# 		BLXalpha: 0.269072
#
# Time Spent 6641.49s:
# 	Generation: 34
# 	Best fitness: 0.442222
# 	Evaluations of fitness: 3411
# 	Substrate probability:
# 		Gauss:    0.256208
# 		Cauchy:   0.204454
# 		DE/best/2:0.309782
# 		BLXalpha: 0.229556
#
# Time Spent 6933.55s:
# 	Generation: 35
# 	Best fitness: 0.444009
# 	Evaluations of fitness: 3507
# 	Substrate probability:
# 		Gauss:    0.256363
# 		Cauchy:   0.228846
# 		DE/best/2:0.270009
# 		BLXalpha: 0.244783
#
# Time Spent 7243.1s:
# 	Generation: 36
# 	Best fitness: 0.457614
# 	Evaluations of fitness: 3602
# 	Substrate probability:
# 		Gauss:    0.252787
# 		Cauchy:   0.261931
# 		DE/best/2:0.197282
# 		BLXalpha: 0.288
#
# Time Spent 7547.07s:
# 	Generation: 37
# 	Best fitness: 0.457614
# 	Evaluations of fitness: 3698
# 	Substrate probability:
# 		Gauss:    0.235155
# 		Cauchy:   0.175441
# 		DE/best/2:0.36188
# 		BLXalpha: 0.227523
#
# Time Spent 7834.95s:
# 	Generation: 38
# 	Best fitness: 0.457614
# 	Evaluations of fitness: 3793
# 	Substrate probability:
# 		Gauss:    0.230706
# 		Cauchy:   0.204452
# 		DE/best/2:0.340002
# 		BLXalpha: 0.22484
#
# Time Spent 8133.12s:
# 	Generation: 39
# 	Best fitness: 0.457614
# 	Evaluations of fitness: 3890
# 	Substrate probability:
# 		Gauss:    0.196047
# 		Cauchy:   0.266363
# 		DE/best/2:0.270997
# 		BLXalpha: 0.266592
#
# Time Spent 8439.55s:
# 	Generation: 40
# 	Best fitness: 0.465402
# 	Evaluations of fitness: 3988
# 	Substrate probability:
# 		Gauss:    0.298219
# 		Cauchy:   0.188616
# 		DE/best/2:0.210501
# 		BLXalpha: 0.302664
#
# Time Spent 8729.76s:
# 	Generation: 41
# 	Best fitness: 0.465402
# 	Evaluations of fitness: 4085
# 	Substrate probability:
# 		Gauss:    0.263575
# 		Cauchy:   0.188745
# 		DE/best/2:0.338375
# 		BLXalpha: 0.209305
#
# Time Spent 9038.38s:
# 	Generation: 42
# 	Best fitness: 0.466346
# 	Evaluations of fitness: 4183
# 	Substrate probability:
# 		Gauss:    0.269991
# 		Cauchy:   0.205959
# 		DE/best/2:0.27222
# 		BLXalpha: 0.251831
#
# Time Spent 9324.35s:
# 	Generation: 43
# 	Best fitness: 0.469909
# 	Evaluations of fitness: 4278
# 	Substrate probability:
# 		Gauss:    0.267091
# 		Cauchy:   0.216346
# 		DE/best/2:0.242493
# 		BLXalpha: 0.27407
#
# Time Spent 9612.87s:
# 	Generation: 44
# 	Best fitness: 0.469909
# 	Evaluations of fitness: 4376
# 	Substrate probability:
# 		Gauss:    0.214235
# 		Cauchy:   0.223636
# 		DE/best/2:0.297967
# 		BLXalpha: 0.264163
#
# Time Spent 9905.27s:
# 	Generation: 45
# 	Best fitness: 0.474819
# 	Evaluations of fitness: 4472
# 	Substrate probability:
# 		Gauss:    0.277325
# 		Cauchy:   0.198944
# 		DE/best/2:0.26938
# 		BLXalpha: 0.254351
#
# Time Spent 10192.84s:
# 	Generation: 46
# 	Best fitness: 0.4834
# 	Evaluations of fitness: 4568
# 	Substrate probability:
# 		Gauss:    0.249062
# 		Cauchy:   0.239344
# 		DE/best/2:0.28446
# 		BLXalpha: 0.227134
#
# Time Spent 10476.07s:
# 	Generation: 47
# 	Best fitness: 0.485593
# 	Evaluations of fitness: 4664
# 	Substrate probability:
# 		Gauss:    0.223882
# 		Cauchy:   0.318716
# 		DE/best/2:0.241827
# 		BLXalpha: 0.215575
#
# Time Spent 10763.4s:
# 	Generation: 48
# 	Best fitness: 0.489247
# 	Evaluations of fitness: 4761
# 	Substrate probability:
# 		Gauss:    0.203481
# 		Cauchy:   0.201127
# 		DE/best/2:0.306862
# 		BLXalpha: 0.28853
#
# Time Spent 11040.32s:
# 	Generation: 49
# 	Best fitness: 0.49385
# 	Evaluations of fitness: 4857
# 	Substrate probability:
# 		Gauss:    0.262018
# 		Cauchy:   0.17809
# 		DE/best/2:0.306387
# 		BLXalpha: 0.253506
#
# Time Spent 11322.79s:
# 	Generation: 50
# 	Best fitness: 0.494004
# 	Evaluations of fitness: 4954
# 	Substrate probability:
# 		Gauss:    0.281142
# 		Cauchy:   0.174939
# 		DE/best/2:0.229219
# 		BLXalpha: 0.314699
#
# Time Spent 11605.43s:
# 	Generation: 51
# 	Best fitness: 0.494004
# 	Evaluations of fitness: 5050
# 	Substrate probability:
# 		Gauss:    0.271195
# 		Cauchy:   0.213338
# 		DE/best/2:0.259661
# 		BLXalpha: 0.255806
#
# Time Spent 11858.46s:
# 	Generation: 52
# 	Best fitness: 0.494004
# 	Evaluations of fitness: 5149
# 	Substrate probability:
# 		Gauss:    0.267145
# 		Cauchy:   0.253886
# 		DE/best/2:0.22485
# 		BLXalpha: 0.254119
#
# Time Spent 12074.15s:
# 	Generation: 53
# 	Best fitness: 0.494433
# 	Evaluations of fitness: 5246
# 	Substrate probability:
# 		Gauss:    0.275813
# 		Cauchy:   0.181414
# 		DE/best/2:0.269553
# 		BLXalpha: 0.273219
#
# Time Spent 12205.41s:
# 	Generation: 54
# 	Best fitness: 0.499058
# 	Evaluations of fitness: 5342
# 	Substrate probability:
# 		Gauss:    0.261219
# 		Cauchy:   0.227005
# 		DE/best/2:0.265258
# 		BLXalpha: 0.246518
#
# Time Spent 12337.5s:
# 	Generation: 55
# 	Best fitness: 0.499058
# 	Evaluations of fitness: 5441
# 	Substrate probability:
# 		Gauss:    0.230075
# 		Cauchy:   0.23391
# 		DE/best/2:0.268706
# 		BLXalpha: 0.267309
#
# Time Spent 12466.95s:
# 	Generation: 56
# 	Best fitness: 0.502656
# 	Evaluations of fitness: 5539
# 	Substrate probability:
# 		Gauss:    0.243766
# 		Cauchy:   0.255179
# 		DE/best/2:0.230265
# 		BLXalpha: 0.27079
#
# Time Spent 12592.83s:
# 	Generation: 57
# 	Best fitness: 0.506854
# 	Evaluations of fitness: 5635
# 	Substrate probability:
# 		Gauss:    0.229493
# 		Cauchy:   0.271
# 		DE/best/2:0.262428
# 		BLXalpha: 0.237079
#
# Time Spent 12721.58s:
# 	Generation: 58
# 	Best fitness: 0.506854
# 	Evaluations of fitness: 5731
# 	Substrate probability:
# 		Gauss:    0.253044
# 		Cauchy:   0.19744
# 		DE/best/2:0.289127
# 		BLXalpha: 0.260389
#
# Time Spent 12851.04s:
# 	Generation: 59
# 	Best fitness: 0.507042
# 	Evaluations of fitness: 5826
# 	Substrate probability:
# 		Gauss:    0.250106
# 		Cauchy:   0.233847
# 		DE/best/2:0.256349
# 		BLXalpha: 0.259697
#
# Time Spent 12977.43s:
# 	Generation: 60
# 	Best fitness: 0.508976
# 	Evaluations of fitness: 5921
# 	Substrate probability:
# 		Gauss:    0.245873
# 		Cauchy:   0.223335
# 		DE/best/2:0.258876
# 		BLXalpha: 0.271917
#
# Time Spent 13110.0s:
# 	Generation: 61
# 	Best fitness: 0.509053
# 	Evaluations of fitness: 6019
# 	Substrate probability:
# 		Gauss:    0.24949
# 		Cauchy:   0.234558
# 		DE/best/2:0.262574
# 		BLXalpha: 0.253377
#
# Time Spent 13239.23s:
# 	Generation: 62
# 	Best fitness: 0.509257
# 	Evaluations of fitness: 6115
# 	Substrate probability:
# 		Gauss:    0.255045
# 		Cauchy:   0.243453
# 		DE/best/2:0.23764
# 		BLXalpha: 0.263862
#
# Time Spent 13373.04s:
# 	Generation: 63
# 	Best fitness: 0.509257
# 	Evaluations of fitness: 6214
# 	Substrate probability:
# 		Gauss:    0.251861
# 		Cauchy:   0.240018
# 		DE/best/2:0.246301
# 		BLXalpha: 0.26182
#
# Time Spent 13499.5s:
# 	Generation: 64
# 	Best fitness: 0.509913
# 	Evaluations of fitness: 6308
# 	Substrate probability:
# 		Gauss:    0.259701
# 		Cauchy:   0.232821
# 		DE/best/2:0.258782
# 		BLXalpha: 0.248696
#
# Time Spent 13627.52s:
# 	Generation: 65
# 	Best fitness: 0.510335
# 	Evaluations of fitness: 6403
# 	Substrate probability:
# 		Gauss:    0.25255
# 		Cauchy:   0.224471
# 		DE/best/2:0.258821
# 		BLXalpha: 0.264159
#
# Time Spent 13759.19s:
# 	Generation: 66
# 	Best fitness: 0.510335
# 	Evaluations of fitness: 6501
# 	Substrate probability:
# 		Gauss:    0.250402
# 		Cauchy:   0.244821
# 		DE/best/2:0.246746
# 		BLXalpha: 0.25803
#
# Time Spent 13888.12s:
# 	Generation: 67
# 	Best fitness: 0.510335
# 	Evaluations of fitness: 6597
# 	Substrate probability:
# 		Gauss:    0.263977
# 		Cauchy:   0.203171
# 		DE/best/2:0.265505
# 		BLXalpha: 0.267346
#
# Time Spent 14018.86s:
# 	Generation: 68
# 	Best fitness: 0.510383
# 	Evaluations of fitness: 6695
# 	Substrate probability:
# 		Gauss:    0.258608
# 		Cauchy:   0.228113
# 		DE/best/2:0.257834
# 		BLXalpha: 0.255445
#
# Time Spent 14148.26s:
# 	Generation: 69
# 	Best fitness: 0.511123
# 	Evaluations of fitness: 6791
# 	Substrate probability:
# 		Gauss:    0.249724
# 		Cauchy:   0.238165
# 		DE/best/2:0.25669
# 		BLXalpha: 0.255421
#
# Time Spent 14277.81s:
# 	Generation: 70
# 	Best fitness: 0.511136
# 	Evaluations of fitness: 6888
# 	Substrate probability:
# 		Gauss:    0.252127
# 		Cauchy:   0.235514
# 		DE/best/2:0.257891
# 		BLXalpha: 0.254468
#
# Time Spent 14405.58s:
# 	Generation: 71
# 	Best fitness: 0.511136
# 	Evaluations of fitness: 6984
# 	Substrate probability:
# 		Gauss:    0.256787
# 		Cauchy:   0.238128
# 		DE/best/2:0.252691
# 		BLXalpha: 0.252394
#
# Time Spent 14526.3s:
# 	Generation: 72
# 	Best fitness: 0.511418
# 	Evaluations of fitness: 7074
# 	Substrate probability:
# 		Gauss:    0.251614
# 		Cauchy:   0.241008
# 		DE/best/2:0.254752
# 		BLXalpha: 0.252626
#
# Time Spent 14649.55s:
# 	Generation: 73
# 	Best fitness: 0.511418
# 	Evaluations of fitness: 7165
# 	Substrate probability:
# 		Gauss:    0.251881
# 		Cauchy:   0.241605
# 		DE/best/2:0.252702
# 		BLXalpha: 0.253812
#
# Time Spent 14861.83s:
# 	Generation: 74
# 	Best fitness: 0.511432
# 	Evaluations of fitness: 7259
# 	Substrate probability:
# 		Gauss:    0.263868
# 		Cauchy:   0.207818
# 		DE/best/2:0.264297
# 		BLXalpha: 0.264017
#
# Time Spent 15081.59s:
# 	Generation: 75
# 	Best fitness: 0.511515
# 	Evaluations of fitness: 7355
# 	Substrate probability:
# 		Gauss:    0.253378
# 		Cauchy:   0.243055
# 		DE/best/2:0.251445
# 		BLXalpha: 0.252122
#
# Time Spent 15239.64s:
# 	Generation: 76
# 	Best fitness: 0.511515
# 	Evaluations of fitness: 7448
# 	Substrate probability:
# 		Gauss:    0.260076
# 		Cauchy:   0.219831
# 		DE/best/2:0.258892
# 		BLXalpha: 0.261201
#
# Time Spent 15360.69s:
# 	Generation: 77
# 	Best fitness: 0.511515
# 	Evaluations of fitness: 7544
# 	Substrate probability:
# 		Gauss:    0.274593
# 		Cauchy:   0.174313
# 		DE/best/2:0.275911
# 		BLXalpha: 0.275183
#
# Time Spent 15477.15s:
# 	Generation: 78
# 	Best fitness: 0.511527
# 	Evaluations of fitness: 7641
# 	Substrate probability:
# 		Gauss:    0.261179
# 		Cauchy:   0.217391
# 		DE/best/2:0.260411
# 		BLXalpha: 0.261019
#
# Time Spent 15586.0s:
# 	Generation: 79
# 	Best fitness: 0.511527
# 	Evaluations of fitness: 7736
# 	Substrate probability:
# 		Gauss:    0.254273
# 		Cauchy:   0.236421
# 		DE/best/2:0.254341
# 		BLXalpha: 0.254965
#
# Time Spent 15691.44s:
# 	Generation: 80
# 	Best fitness: 0.511579
# 	Evaluations of fitness: 7830
# 	Substrate probability:
# 		Gauss:    0.252717
# 		Cauchy:   0.241619
# 		DE/best/2:0.25289
# 		BLXalpha: 0.252773
#
# Time Spent 15797.11s:
# 	Generation: 81
# 	Best fitness: 0.51166
# 	Evaluations of fitness: 7926
# 	Substrate probability:
# 		Gauss:    0.257163
# 		Cauchy:   0.228077
# 		DE/best/2:0.257554
# 		BLXalpha: 0.257207
#
# Time Spent 15899.49s:
# 	Generation: 82
# 	Best fitness: 0.51166
# 	Evaluations of fitness: 8020
# 	Substrate probability:
# 		Gauss:    0.251139
# 		Cauchy:   0.245704
# 		DE/best/2:0.251883
# 		BLXalpha: 0.251274
#
# Time Spent 16001.55s:
# 	Generation: 83
# 	Best fitness: 0.51166
# 	Evaluations of fitness: 8113
# 	Substrate probability:
# 		Gauss:    0.258107
# 		Cauchy:   0.225439
# 		DE/best/2:0.25817
# 		BLXalpha: 0.258284
#
# Time Spent 16103.74s:
# 	Generation: 84
# 	Best fitness: 0.51166
# 	Evaluations of fitness: 8208
# 	Substrate probability:
# 		Gauss:    0.255949
# 		Cauchy:   0.231488
# 		DE/best/2:0.256438
# 		BLXalpha: 0.256125
#
# Time Spent 16208.27s:
# 	Generation: 85
# 	Best fitness: 0.511712
# 	Evaluations of fitness: 8305
# 	Substrate probability:
# 		Gauss:    0.252375
# 		Cauchy:   0.242294
# 		DE/best/2:0.252801
# 		BLXalpha: 0.252529
#
# Time Spent 16308.34s:
# 	Generation: 86
# 	Best fitness: 0.511765
# 	Evaluations of fitness: 8399
# 	Substrate probability:
# 		Gauss:    0.253508
# 		Cauchy:   0.23916
# 		DE/best/2:0.253886
# 		BLXalpha: 0.253446
#
# Time Spent 16407.27s:
# 	Generation: 87
# 	Best fitness: 0.511765
# 	Evaluations of fitness: 8493
# 	Substrate probability:
# 		Gauss:    0.258203
# 		Cauchy:   0.225107
# 		DE/best/2:0.258506
# 		BLXalpha: 0.258184
#
# Time Spent 16504.1s:
# 	Generation: 88
# 	Best fitness: 0.511765
# 	Evaluations of fitness: 8585
# 	Substrate probability:
# 		Gauss:    0.253897
# 		Cauchy:   0.238172
# 		DE/best/2:0.25399
# 		BLXalpha: 0.253941
#
# Time Spent 16598.53s:
# 	Generation: 89
# 	Best fitness: 0.511765
# 	Evaluations of fitness: 8675
# 	Substrate probability:
# 		Gauss:    0.255497
# 		Cauchy:   0.233316
# 		DE/best/2:0.255747
# 		BLXalpha: 0.25544
#
# Time Spent 16694.88s:
# 	Generation: 90
# 	Best fitness: 0.511793
# 	Evaluations of fitness: 8767
# 	Substrate probability:
# 		Gauss:    0.266126
# 		Cauchy:   0.201133
# 		DE/best/2:0.266315
# 		BLXalpha: 0.266426
#
# Time Spent 16791.6s:
# 	Generation: 91
# 	Best fitness: 0.511805
# 	Evaluations of fitness: 8859
# 	Substrate probability:
# 		Gauss:    0.266584
# 		Cauchy:   0.200308
# 		DE/best/2:0.266119
# 		BLXalpha: 0.26699
#
# Time Spent 16889.16s:
# 	Generation: 92
# 	Best fitness: 0.511841
# 	Evaluations of fitness: 8952
# 	Substrate probability:
# 		Gauss:    0.253818
# 		Cauchy:   0.238607
# 		DE/best/2:0.254029
# 		BLXalpha: 0.253545
#
# Time Spent 16989.83s:
# 	Generation: 93
# 	Best fitness: 0.511857
# 	Evaluations of fitness: 9048
# 	Substrate probability:
# 		Gauss:    0.253118
# 		Cauchy:   0.240374
# 		DE/best/2:0.253384
# 		BLXalpha: 0.253124
#
# Time Spent 17094.33s:
# 	Generation: 94
# 	Best fitness: 0.511858
# 	Evaluations of fitness: 9146
# 	Substrate probability:
# 		Gauss:    0.260266
# 		Cauchy:   0.218667
# 		DE/best/2:0.260629
# 		BLXalpha: 0.260438
#
# Time Spent 17197.6s:
# 	Generation: 95
# 	Best fitness: 0.511858
# 	Evaluations of fitness: 9244
# 	Substrate probability:
# 		Gauss:    0.254448
# 		Cauchy:   0.235833
# 		DE/best/2:0.254903
# 		BLXalpha: 0.254816
#
# Time Spent 17300.19s:
# 	Generation: 96
# 	Best fitness: 0.511858
# 	Evaluations of fitness: 9340
# 	Substrate probability:
# 		Gauss:    0.252117
# 		Cauchy:   0.243858
# 		DE/best/2:0.252037
# 		BLXalpha: 0.251988
#
# Time Spent 17405.08s:
# 	Generation: 97
# 	Best fitness: 0.511858
# 	Evaluations of fitness: 9439
# 	Substrate probability:
# 		Gauss:    0.253208
# 		Cauchy:   0.240455
# 		DE/best/2:0.253085
# 		BLXalpha: 0.253252
#
# Time Spent 17511.08s:
# 	Generation: 98
# 	Best fitness: 0.511858
# 	Evaluations of fitness: 9539
# 	Substrate probability:
# 		Gauss:    0.253709
# 		Cauchy:   0.238916
# 		DE/best/2:0.25369
# 		BLXalpha: 0.253684
#
# Time Spent 17615.17s:
# 	Generation: 99
# 	Best fitness: 0.511858
# 	Evaluations of fitness: 9638
# 	Substrate probability:
# 		Gauss:    0.254495
# 		Cauchy:   0.236427
# 		DE/best/2:0.254526
# 		BLXalpha: 0.254551
#
# Time Spent 17719.38s:
# 	Generation: 100
# 	Best fitness: 0.51187
# 	Evaluations of fitness: 9737
# 	Substrate probability:
# 		Gauss:    0.261671
# 		Cauchy:   0.215014
# 		DE/best/2:0.2616
# 		BLXalpha: 0.261715
#
# Rows: 4 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (4): code, order, codedown, supha
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Optimizing basin with code 3268.
#
#
# Time Spent 272.98s:
# 	Generation: 1
# 	Best fitness: 0.522114
# 	Evaluations of fitness: 258
# 	Substrate probability:
# 		Gauss:    0.25
# 		Cauchy:   0.25
# 		DE/best/2:0.25
# 		BLXalpha: 0.25
#
# Time Spent 375.99s:
# 	Generation: 2
# 	Best fitness: 0.640095
# 	Evaluations of fitness: 356
# 	Substrate probability:
# 		Gauss:    0.016692
# 		Cauchy:   0.541282
# 		DE/best/2:0.437115
# 		BLXalpha: 0.004911
#
# Time Spent 476.88s:
# 	Generation: 3
# 	Best fitness: 0.64452
# 	Evaluations of fitness: 452
# 	Substrate probability:
# 		Gauss:    0.004902
# 		Cauchy:   0.985226
# 		DE/best/2:0.00497
# 		BLXalpha: 0.004902
#
# Time Spent 579.71s:
# 	Generation: 4
# 	Best fitness: 0.64452
# 	Evaluations of fitness: 549
# 	Substrate probability:
# 		Gauss:    0.004902
# 		Cauchy:   0.985294
# 		DE/best/2:0.004902
# 		BLXalpha: 0.004902
#
# Time Spent 679.84s:
# 	Generation: 5
# 	Best fitness: 0.644758
# 	Evaluations of fitness: 643
# 	Substrate probability:
# 		Gauss:    0.004902
# 		Cauchy:   0.985294
# 		DE/best/2:0.004902
# 		BLXalpha: 0.004902
#
# Time Spent 785.91s:
# 	Generation: 6
# 	Best fitness: 0.647769
# 	Evaluations of fitness: 741
# 	Substrate probability:
# 		Gauss:    0.019419
# 		Cauchy:   0.93898
# 		DE/best/2:0.004902
# 		BLXalpha: 0.036699
#
# Time Spent 888.06s:
# 	Generation: 7
# 	Best fitness: 0.647769
# 	Evaluations of fitness: 837
# 	Substrate probability:
# 		Gauss:    0.016341
# 		Cauchy:   0.973854
# 		DE/best/2:0.004902
# 		BLXalpha: 0.004903
#
# Time Spent 989.45s:
# 	Generation: 8
# 	Best fitness: 0.647769
# 	Evaluations of fitness: 932
# 	Substrate probability:
# 		Gauss:    0.063175
# 		Cauchy:   0.927021
# 		DE/best/2:0.004902
# 		BLXalpha: 0.004902
#
# Time Spent 1090.16s:
# 	Generation: 9
# 	Best fitness: 0.647769
# 	Evaluations of fitness: 1024
# 	Substrate probability:
# 		Gauss:    0.489841
# 		Cauchy:   0.498727
# 		DE/best/2:0.004902
# 		BLXalpha: 0.006529
#
# Time Spent 1189.09s:
# 	Generation: 10
# 	Best fitness: 0.648658
# 	Evaluations of fitness: 1117
# 	Substrate probability:
# 		Gauss:    0.489519
# 		Cauchy:   0.500677
# 		DE/best/2:0.004902
# 		BLXalpha: 0.004902
#
# Time Spent 1288.26s:
# 	Generation: 11
# 	Best fitness: 0.648694
# 	Evaluations of fitness: 1212
# 	Substrate probability:
# 		Gauss:    0.481626
# 		Cauchy:   0.50857
# 		DE/best/2:0.004902
# 		BLXalpha: 0.004902
#
# Time Spent 1386.35s:
# 	Generation: 12
# 	Best fitness: 0.648694
# 	Evaluations of fitness: 1305
# 	Substrate probability:
# 		Gauss:    0.348726
# 		Cauchy:   0.334033
# 		DE/best/2:0.006852
# 		BLXalpha: 0.310388
#
# Time Spent 1486.83s:
# 	Generation: 13
# 	Best fitness: 0.653425
# 	Evaluations of fitness: 1401
# 	Substrate probability:
# 		Gauss:    0.329188
# 		Cauchy:   0.316873
# 		DE/best/2:0.022344
# 		BLXalpha: 0.331596
#
# Time Spent 1585.62s:
# 	Generation: 14
# 	Best fitness: 0.653425
# 	Evaluations of fitness: 1495
# 	Substrate probability:
# 		Gauss:    0.245232
# 		Cauchy:   0.268957
# 		DE/best/2:0.240396
# 		BLXalpha: 0.245416
#
# Time Spent 1686.74s:
# 	Generation: 15
# 	Best fitness: 0.653425
# 	Evaluations of fitness: 1590
# 	Substrate probability:
# 		Gauss:    0.241587
# 		Cauchy:   0.240646
# 		DE/best/2:0.259948
# 		BLXalpha: 0.257819
#
# Time Spent 1788.09s:
# 	Generation: 16
# 	Best fitness: 0.655481
# 	Evaluations of fitness: 1685
# 	Substrate probability:
# 		Gauss:    0.253651
# 		Cauchy:   0.253287
# 		DE/best/2:0.251387
# 		BLXalpha: 0.241676
#
# Time Spent 1891.69s:
# 	Generation: 17
# 	Best fitness: 0.655943
# 	Evaluations of fitness: 1784
# 	Substrate probability:
# 		Gauss:    0.243049
# 		Cauchy:   0.254255
# 		DE/best/2:0.25627
# 		BLXalpha: 0.246425
#
# Time Spent 1994.44s:
# 	Generation: 18
# 	Best fitness: 0.659047
# 	Evaluations of fitness: 1882
# 	Substrate probability:
# 		Gauss:    0.246223
# 		Cauchy:   0.246675
# 		DE/best/2:0.258497
# 		BLXalpha: 0.248605
#
# Time Spent 2094.82s:
# 	Generation: 19
# 	Best fitness: 0.661832
# 	Evaluations of fitness: 1978
# 	Substrate probability:
# 		Gauss:    0.240819
# 		Cauchy:   0.242973
# 		DE/best/2:0.26813
# 		BLXalpha: 0.248078
#
# Time Spent 2194.22s:
# 	Generation: 20
# 	Best fitness: 0.662451
# 	Evaluations of fitness: 2072
# 	Substrate probability:
# 		Gauss:    0.25138
# 		Cauchy:   0.235572
# 		DE/best/2:0.270441
# 		BLXalpha: 0.242607
#
# Time Spent 2294.96s:
# 	Generation: 21
# 	Best fitness: 0.662451
# 	Evaluations of fitness: 2167
# 	Substrate probability:
# 		Gauss:    0.23453
# 		Cauchy:   0.247732
# 		DE/best/2:0.253249
# 		BLXalpha: 0.264489
#
# Time Spent 2396.27s:
# 	Generation: 22
# 	Best fitness: 0.662684
# 	Evaluations of fitness: 2263
# 	Substrate probability:
# 		Gauss:    0.242028
# 		Cauchy:   0.229921
# 		DE/best/2:0.267984
# 		BLXalpha: 0.260066
#
# Time Spent 2497.28s:
# 	Generation: 23
# 	Best fitness: 0.662684
# 	Evaluations of fitness: 2359
# 	Substrate probability:
# 		Gauss:    0.250332
# 		Cauchy:   0.24408
# 		DE/best/2:0.25437
# 		BLXalpha: 0.251218
#
# Time Spent 2597.87s:
# 	Generation: 24
# 	Best fitness: 0.66383
# 	Evaluations of fitness: 2455
# 	Substrate probability:
# 		Gauss:    0.253454
# 		Cauchy:   0.247547
# 		DE/best/2:0.247252
# 		BLXalpha: 0.251747
#
# Time Spent 2698.34s:
# 	Generation: 25
# 	Best fitness: 0.66383
# 	Evaluations of fitness: 2551
# 	Substrate probability:
# 		Gauss:    0.252343
# 		Cauchy:   0.239776
# 		DE/best/2:0.257886
# 		BLXalpha: 0.249996
#
# Time Spent 2800.84s:
# 	Generation: 26
# 	Best fitness: 0.666556
# 	Evaluations of fitness: 2649
# 	Substrate probability:
# 		Gauss:    0.247839
# 		Cauchy:   0.249347
# 		DE/best/2:0.251841
# 		BLXalpha: 0.250974
#
# Time Spent 2904.25s:
# 	Generation: 27
# 	Best fitness: 0.666556
# 	Evaluations of fitness: 2746
# 	Substrate probability:
# 		Gauss:    0.250062
# 		Cauchy:   0.237521
# 		DE/best/2:0.263647
# 		BLXalpha: 0.24877
#
# Time Spent 3002.66s:
# 	Generation: 28
# 	Best fitness: 0.666556
# 	Evaluations of fitness: 2840
# 	Substrate probability:
# 		Gauss:    0.250992
# 		Cauchy:   0.23694
# 		DE/best/2:0.259059
# 		BLXalpha: 0.25301
#
# Time Spent 3101.11s:
# 	Generation: 29
# 	Best fitness: 0.666556
# 	Evaluations of fitness: 2934
# 	Substrate probability:
# 		Gauss:    0.255483
# 		Cauchy:   0.241632
# 		DE/best/2:0.249052
# 		BLXalpha: 0.253832
#
# Time Spent 3201.3s:
# 	Generation: 30
# 	Best fitness: 0.666556
# 	Evaluations of fitness: 3030
# 	Substrate probability:
# 		Gauss:    0.245476
# 		Cauchy:   0.247077
# 		DE/best/2:0.254737
# 		BLXalpha: 0.252711
#
# Time Spent 3303.15s:
# 	Generation: 31
# 	Best fitness: 0.666556
# 	Evaluations of fitness: 3127
# 	Substrate probability:
# 		Gauss:    0.258537
# 		Cauchy:   0.231333
# 		DE/best/2:0.253358
# 		BLXalpha: 0.256773
#
# Time Spent 3404.3s:
# 	Generation: 32
# 	Best fitness: 0.666565
# 	Evaluations of fitness: 3223
# 	Substrate probability:
# 		Gauss:    0.249889
# 		Cauchy:   0.244883
# 		DE/best/2:0.252152
# 		BLXalpha: 0.253076
#
# Time Spent 3506.81s:
# 	Generation: 33
# 	Best fitness: 0.666565
# 	Evaluations of fitness: 3321
# 	Substrate probability:
# 		Gauss:    0.254863
# 		Cauchy:   0.243474
# 		DE/best/2:0.249741
# 		BLXalpha: 0.251922
#
# Time Spent 3606.43s:
# 	Generation: 34
# 	Best fitness: 0.666565
# 	Evaluations of fitness: 3416
# 	Substrate probability:
# 		Gauss:    0.25294
# 		Cauchy:   0.243973
# 		DE/best/2:0.251614
# 		BLXalpha: 0.251473
#
# Time Spent 3708.33s:
# 	Generation: 35
# 	Best fitness: 0.666571
# 	Evaluations of fitness: 3513
# 	Substrate probability:
# 		Gauss:    0.253017
# 		Cauchy:   0.240982
# 		DE/best/2:0.252822
# 		BLXalpha: 0.253179
#
# Time Spent 3812.87s:
# 	Generation: 36
# 	Best fitness: 0.666571
# 	Evaluations of fitness: 3613
# 	Substrate probability:
# 		Gauss:    0.250037
# 		Cauchy:   0.250103
# 		DE/best/2:0.249878
# 		BLXalpha: 0.249981
#
# Time Spent 3915.67s:
# 	Generation: 37
# 	Best fitness: 0.667686
# 	Evaluations of fitness: 3711
# 	Substrate probability:
# 		Gauss:    0.251279
# 		Cauchy:   0.24611
# 		DE/best/2:0.251322
# 		BLXalpha: 0.251289
#
# Time Spent 4016.1s:
# 	Generation: 38
# 	Best fitness: 0.670618
# 	Evaluations of fitness: 3807
# 	Substrate probability:
# 		Gauss:    0.250779
# 		Cauchy:   0.243004
# 		DE/best/2:0.255805
# 		BLXalpha: 0.250412
#
# Time Spent 4120.73s:
# 	Generation: 39
# 	Best fitness: 0.675794
# 	Evaluations of fitness: 3906
# 	Substrate probability:
# 		Gauss:    0.244215
# 		Cauchy:   0.261571
# 		DE/best/2:0.248794
# 		BLXalpha: 0.24542
#
# Time Spent 4225.27s:
# 	Generation: 40
# 	Best fitness: 0.678689
# 	Evaluations of fitness: 4003
# 	Substrate probability:
# 		Gauss:    0.240911
# 		Cauchy:   0.239194
# 		DE/best/2:0.280293
# 		BLXalpha: 0.239601
#
# Time Spent 4324.93s:
# 	Generation: 41
# 	Best fitness: 0.678689
# 	Evaluations of fitness: 4097
# 	Substrate probability:
# 		Gauss:    0.247082
# 		Cauchy:   0.206733
# 		DE/best/2:0.289409
# 		BLXalpha: 0.256776
#
# Time Spent 4427.3s:
# 	Generation: 42
# 	Best fitness: 0.679712
# 	Evaluations of fitness: 4194
# 	Substrate probability:
# 		Gauss:    0.251448
# 		Cauchy:   0.220168
# 		DE/best/2:0.2642
# 		BLXalpha: 0.264185
#
# Time Spent 4527.98s:
# 	Generation: 43
# 	Best fitness: 0.679771
# 	Evaluations of fitness: 4289
# 	Substrate probability:
# 		Gauss:    0.249237
# 		Cauchy:   0.224578
# 		DE/best/2:0.267337
# 		BLXalpha: 0.258848
#
# Time Spent 4729.62s:
# 	Generation: 44
# 	Best fitness: 0.680072
# 	Evaluations of fitness: 4385
# 	Substrate probability:
# 		Gauss:    0.247011
# 		Cauchy:   0.240457
# 		DE/best/2:0.25948
# 		BLXalpha: 0.253052
#
# Time Spent 4991.28s:
# 	Generation: 45
# 	Best fitness: 0.680667
# 	Evaluations of fitness: 4479
# 	Substrate probability:
# 		Gauss:    0.250356
# 		Cauchy:   0.241762
# 		DE/best/2:0.257452
# 		BLXalpha: 0.25043
#
# Time Spent 5258.92s:
# 	Generation: 46
# 	Best fitness: 0.680667
# 	Evaluations of fitness: 4573
# 	Substrate probability:
# 		Gauss:    0.245097
# 		Cauchy:   0.25426
# 		DE/best/2:0.251299
# 		BLXalpha: 0.249343
# R[write to console]:
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# Cell In[26], line 29
#      25 c = CRO_SL(objfunc, substrates_real, params)
#      27 print(f"Optimizing basin with code {basin_code}.\n\n")
# ---> 29 c.safe_optimize()
#      30 basin_params[basin_code] = c.best_solution()
#      32 if codedown not in agg_q:
#
# File ~/Documents/invAI/HydrologyProblem/PyCRO_SL/CRO_SL.py:169, in CRO_SL.safe_optimize(self)
#     167 result = (np.array([]), 0)
#     168 try:
# --> 169     result = self.optimize()
#     170 except KeyboardInterrupt:
#     171     print("stopped early")
#
# File ~/Documents/invAI/HydrologyProblem/PyCRO_SL/CRO_SL.py:154, in CRO_SL.optimize(self)
#     152 while not self.stopping_condition(gen, real_time_start):
#     153     prog = self.progress(gen, real_time_start)
# --> 154     self.step(prog, depredate=True)
#     155     gen += 1
#     156     if self.verbose and time.time() - display_timer > self.v_timer:
#
# File ~/Documents/invAI/HydrologyProblem/PyCRO_SL/CRO_SL.py:82, in CRO_SL.step(self, progress, depredate, classic)
#      79 if not classic:
#      80     self.population.generate_substrates(progress)
# ---> 82 larvae = self.population.evolve_with_substrates()
#      84 self.population.larvae_setting(larvae)
#      86 if depredate:
#
# File ~/Documents/invAI/HydrologyProblem/PyCRO_SL/CoralPopulation.py:253, in CoralPopulation.evolve_with_substrates(self)
#     251     # Get data of the current substrate
#     252     if self.dyn_method == "fitness" or self.dyn_method == "diff":
# --> 253         self.substrate_data[s_idx].append(new_coral.get_fitness())
#     254 else:
#     255     new_sol = self.objfunc.random_solution()
#
# File ~/Documents/invAI/HydrologyProblem/PyCRO_SL/CoralPopulation.py:31, in Coral.get_fitness(self)
#      29 def get_fitness(self):
#      30     if not self.fitness_calculated:
# ---> 31         self.fitness = self.objfunc.fitness(self.solution)
#      32         self.fitness_calculated = True
#      33     return self.fitness
#
# File ~/Documents/invAI/HydrologyProblem/PyCRO_SL/AbsObjetiveFunc.py:21, in AbsObjetiveFunc.fitness(self, solution)
#      19 def fitness(self, solution):
#      20     self.counter += 1
# ---> 21     return self.factor * self.objetive(solution)
#
# Cell In[3], line 25, in HydroProblemSemidist.objetive(self, solution)
#      24 def objetive(self, solution):
# ---> 25     metrics = self.exec_function_r(self.model_used, solution, self.basin_code, self.prev_q)
#      26     if self.metric == "MSE":
#      27         return float(metrics[0])
#
# File ~/.local/lib/python3.10/site-packages/rpy2/robjects/functions.py:204, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     202         v = kwargs.pop(k)
#     203         kwargs[r_k] = v
# --> 204 return (super(SignatureTranslatedFunction, self)
#     205         .__call__(*args, **kwargs))
#
# File ~/.local/lib/python3.10/site-packages/rpy2/robjects/functions.py:127, in Function.__call__(self, *args, **kwargs)
#     125     else:
#     126         new_kwargs[k] = cv.py2rpy(v)
# --> 127 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     128 res = cv.rpy2py(res)
#     129 return res
#
# File ~/.local/lib/python3.10/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#      47     return _cdata_to_rinterface(cdata)
#
# File ~/.local/lib/python3.10/site-packages/rpy2/rinterface.py:817, in SexpClosure.__call__(self, *args, **kwargs)
#     810     res = rmemory.protect(
#     811         openrlib.rlib.R_tryEval(
#     812             call_r,
#     813             call_context.__sexp__._cdata,
#     814             error_occured)
#     815     )
#     816     if error_occured[0]:
# --> 817         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     818 return res
#
# RRuntimeError: Cannot determine terminal size (system error 25, Inappropriate ioctl for device) @tty.c:31 (clic_tty_size)

# %%
result = []
for i in basins["code"]:
    result += [basin_params[i][0]]
result = np.array(result)

np.savetxt("config_nooptim.csv", result, delimiter=",")
